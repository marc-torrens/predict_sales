# %% [markdown]
# In this notebook we process all the data, generating a single pickle with clean data. We have the following steps:
# - Deal with oultiers and missing periods in the time series (train, test, oil prices)
# - Join the store info
# - Process the holidays data and join in too
# - Deal with NaN values in oil data and join
# - Process transactions and join

# %%
import pandas as pd
import plotly.express as px

# %%
df_train = pd.read_csv('../../data/train.csv')

# %%
# Change type of columns
df_train['date'] = pd.to_datetime(df_train['date'])
df_train['family'] = df_train['family'].astype(str)
df_train.head(5)
# Out:
#    id       date  store_nbr      family  sales  onpromotion
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1 2013-01-01          1   BABY CARE    0.0            0
# 2   2 2013-01-01          1      BEAUTY    0.0            0
# 3   3 2013-01-01          1   BEVERAGES    0.0            0
# 4   4 2013-01-01          1       BOOKS    0.0            0

# %%
sample = df_train.loc[(df_train['store_nbr'] == 1) & (df_train['family'] == 'PRODUCE')]
fig = px.line(sample, 'date', 'sales')
fig.show()

# %% [markdown]
# We can see that in this case the period without data aren't exactly 0, so we have to detect also these cases

# %%
# We will detect large periods where the data is less than a certain value
